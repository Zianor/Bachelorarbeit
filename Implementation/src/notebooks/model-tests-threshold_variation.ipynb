# %%
from own_models_train import get_final_paths, get_final_column_names
from eda_utils import get_latex_column_names
import utils
from estimators import *
from IPython.display import display, Markdown

plt.rcParams.update(utils.get_plt_settings())

# %%
models_rf_clf = {
    'RF_Clf_s10_default_h5': None,
    'RF_Clf_s10_default_h10': None,
    'RF_Clf_s10_default_h15': None,
    'RF_Clf_s10_default_h20': None
}
hr_thresholds = [5, 10, 15, 20]
for path, hr_threshold in zip(models_rf_clf.keys(), hr_thresholds):
    print(path)
    feature_selection = get_final_column_names()
    models_rf_clf[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection, hr_threshold=hr_threshold)
# Out:
# RF_Clf_s10_default_h5
# RF_Clf_s10_default_h10
# RF_Clf_s10_default_h15
# RF_Clf_s10_default_h20

# %%
display(Markdown("## RF_Clf_h5"))
models_rf_clf['RF_Clf_s10_default_h5'].print_short_report()
display(Markdown("## RF_Clf_h10"))
models_rf_clf['RF_Clf_s10_default_h10'].print_short_report()
display(Markdown("## RF_Clf_h15"))
models_rf_clf['RF_Clf_s10_default_h15'].print_short_report()
display(Markdown("## RF_Clf_h20"))
models_rf_clf['RF_Clf_s10_default_h20'].print_short_report()
# Out:
# ## RF_Clf_h5
# AUC: 0.78
# F1: 0.59
# Coverage klassifiziert      : 29.30 %
# Coverage annotiert          : 32.61 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 11.39 +- 16.86
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# ## RF_Clf_h10
# AUC: 0.75
# F1: 0.60
# Coverage klassifiziert      : 34.90 %
# Coverage annotiert          : 43.21 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 11.86 +- 16.61
# MAE auf als informativ annotierten Segmenten:  3.28 +- 2.65
# ## RF_Clf_h15
# AUC: 0.73
# F1: 0.64
# Coverage klassifiziert      : 42.46 %
# Coverage annotiert          : 51.64 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 12.44 +- 16.31
# MAE auf als informativ annotierten Segmenten:  4.78 +- 4.22
# ## RF_Clf_h20
# AUC: 0.73
# F1: 0.70
# Coverage klassifiziert      : 53.78 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# ...

# %%
models_xgb_clf = {
    'XGB_Clf_s10_default_h5': None,
    'XGB_Clf_s10_default_h10': None,
    'XGB_Clf_s10_default_h15': None,
    'XGB_Clf_s10_default_h20': None
}
hr_thresholds = [5, 10, 15, 20]
for path, hr_threshold in zip(models_xgb_clf.keys(), hr_thresholds):
    print(path)
    feature_selection = get_final_column_names()
    models_xgb_clf[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection, hr_threshold=hr_threshold)
# Out:
# XGB_Clf_s10_default_h5
# XGB_Clf_s10_default_h10
# XGB_Clf_s10_default_h15
# XGB_Clf_s10_default_h20

# %%
display(Markdown("## XGB_Clf_h5"))
models_xgb_clf['XGB_Clf_s10_default_h5'].print_short_report()
display(Markdown("## XGB_Clf_h10"))
models_xgb_clf['XGB_Clf_s10_default_h10'].print_short_report()
display(Markdown("## XGB_Clf_h15"))
models_xgb_clf['XGB_Clf_s10_default_h15'].print_short_report()
display(Markdown("## XGB_Clf_h20"))
models_xgb_clf['XGB_Clf_s10_default_h20'].print_short_report()
# Out:
# ## XGB_Clf_h5
# AUC: 0.77
# F1: 0.59
# Coverage klassifiziert      : 31.51 %
# Coverage annotiert          : 32.61 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 11.39 +- 16.24
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# ## XGB_Clf_h10
# AUC: 0.75
# F1: 0.63
# Coverage klassifiziert      : 41.99 %
# Coverage annotiert          : 43.21 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 12.44 +- 16.15
# MAE auf als informativ annotierten Segmenten:  3.28 +- 2.65
# ## XGB_Clf_h15
# AUC: 0.73
# F1: 0.67
# Coverage klassifiziert      : 51.15 %
# Coverage annotiert          : 51.64 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 13.23 +- 15.95
# MAE auf als informativ annotierten Segmenten:  4.78 +- 4.22
# ## XGB_Clf_h20
# AUC: 0.73
# F1: 0.73
# Coverage klassifiziert      : 59.73 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# ...

# %%
models_rf_regr = {
    'RF_Regr_s10_default_h5': None,
    'RF_Regr_s10_default_h10': None,
    'RF_Regr_s10_default_h15': None,
    'RF_Regr_s10_default_h20': None
}
hr_thresholds = [5, 10, 15, 20]
for path, hr_threshold in zip(models_rf_regr.keys(), hr_thresholds):
    print(path)
    feature_selection = get_final_column_names()
    models_rf_regr[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection, hr_threshold=hr_threshold)
# Out:
# RF_Regr_s10_default_h5
# RF_Regr_s10_default_h10
# RF_Regr_s10_default_h15
# RF_Regr_s10_default_h20

# %%
display(Markdown("## RF_Regr_h5"))
models_rf_regr['RF_Regr_s10_default_h5'].print_short_report()
display(Markdown("## RF_Regr_h10"))
models_rf_regr['RF_Regr_s10_default_h10'].print_short_report()
display(Markdown("## RF_Regr_h15"))
models_rf_regr['RF_Regr_s10_default_h15'].print_short_report()
display(Markdown("## RF_Regr_h20"))
models_rf_regr['RF_Regr_s10_default_h20'].print_short_report()
# Out:
# ## RF_Regr_h5
# AUC: 0.77
# F1: 0.52
# Coverage klassifiziert      : 20.19 %
# Coverage annotiert          : 32.61 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 9.83 +- 15.42
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# ## RF_Regr_h10
# AUC: 0.75
# F1: 0.64
# Coverage klassifiziert      : 46.36 %
# Coverage annotiert          : 43.21 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 12.57 +- 15.99
# MAE auf als informativ annotierten Segmenten:  3.28 +- 2.65
# ## RF_Regr_h15
# AUC: 0.74
# F1: 0.72
# Coverage klassifiziert      : 71.16 %
# Coverage annotiert          : 51.64 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 14.61 +- 16.02
# MAE auf als informativ annotierten Segmenten:  4.78 +- 4.22
# ## RF_Regr_h20
# AUC: 0.73
# F1: 0.78
# Coverage klassifiziert      : 79.47 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# ...

# %%
models_xgb_regr = {
    'XGB_Regr_s10_default_h5': None,
    'XGB_Regr_s10_default_h10': None,
    'XGB_Regr_s10_default_h15': None,
    'XGB_Regr_s10_default_h20': None
}
hr_thresholds = [5, 10, 15, 20]
for path, hr_threshold in zip(models_xgb_regr.keys(), hr_thresholds):
    print(path)
    feature_selection = get_final_column_names()
    models_xgb_regr[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection, hr_threshold=hr_threshold)
# Out:
# XGB_Regr_s10_default_h5
# XGB_Regr_s10_default_h10
# XGB_Regr_s10_default_h15
# XGB_Regr_s10_default_h20

# %%
display(Markdown("## XGB_Regr_h5"))
models_xgb_regr['XGB_Regr_s10_default_h5'].print_short_report()
display(Markdown("## XGB_Regr_h10"))
models_xgb_regr['XGB_Regr_s10_default_h10'].print_short_report()
display(Markdown("## XGB_Regr_h15"))
models_xgb_regr['XGB_Regr_s10_default_h15'].print_short_report()
display(Markdown("## XGB_Regr_h20"))
models_xgb_regr['XGB_Regr_s10_default_h20'].print_short_report()
# Out:
# ## XGB_Regr_h5
# AUC: 0.75
# F1: 0.55
# Coverage klassifiziert      : 26.76 %
# Coverage annotiert          : 32.61 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 10.52 +- 14.94
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# ## XGB_Regr_h10
# AUC: 0.74
# F1: 0.64
# Coverage klassifiziert      : 47.59 %
# Coverage annotiert          : 43.21 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 12.66 +- 15.37
# MAE auf als informativ annotierten Segmenten:  3.28 +- 2.65
# ## XGB_Regr_h15
# AUC: 0.73
# F1: 0.71
# Coverage klassifiziert      : 63.74 %
# Coverage annotiert          : 51.64 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 14.04 +- 15.72
# MAE auf als informativ annotierten Segmenten:  4.78 +- 4.22
# ## XGB_Regr_h20
# AUC: 0.73
# F1: 0.77
# Coverage klassifiziert      : 74.18 %
# Coverage annotiert          : 59.45 %
# ...

# %%
display(Markdown("## XGB_Regr_h5"))
models_xgb_regr['XGB_Regr_s10_default_h5'].print_model_test_report()
display(Markdown("## XGB_Regr_h20"))
models_xgb_regr['XGB_Regr_s10_default_h20'].print_model_test_report()
# Out:
# ## XGB_Regr_h5
# AUC: 0.75
# F1-Score: 0.55
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.78      0.85      0.81    170982
#     informative       0.61      0.50      0.55     82721
#
#        accuracy                           0.73    253703
#       macro avg       0.69      0.67      0.68    253703
#    weighted avg       0.72      0.73      0.73    253703
#
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 10.52 +- 14.94
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# MSE auf als informativ klassifizierten Segmenten: 333.89
# MSE auf als informativ annotierten Segmenten:  5.68
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 26.76 %
# Coverage annotiert          : 32.61 %
#
# ...

# %%
display(Markdown("## RF_Regr_h5"))
models_rf_regr['RF_Regr_s10_default_h5'].print_model_test_report()
display(Markdown("## RF_Regr_h20"))
models_rf_regr['RF_Regr_s10_default_h20'].print_model_test_report()
# Out:
# ## RF_Regr_h5
# AUC: 0.77
# F1-Score: 0.52
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.76      0.90      0.83    170982
#     informative       0.68      0.42      0.52     82721
#
#        accuracy                           0.75    253703
#       macro avg       0.72      0.66      0.67    253703
#    weighted avg       0.74      0.75      0.73    253703
#
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 9.83 +- 15.42
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# MSE auf als informativ klassifizierten Segmenten: 334.39
# MSE auf als informativ annotierten Segmenten:  5.68
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 20.19 %
# Coverage annotiert          : 32.61 %
#
# ...

# %%
display(Markdown("## XGB_Clf_h5"))
models_xgb_clf['XGB_Clf_s10_default_h5'].print_model_test_report()
display(Markdown("## XGB_Clf_h20"))
models_xgb_clf['XGB_Clf_s10_default_h20'].print_model_test_report()
# Out:
# ## XGB_Clf_h5
# AUC: 0.77
# F1-Score: 0.59
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.80      0.81      0.81    170982
#     informative       0.60      0.58      0.59     82721
#
#        accuracy                           0.74    253703
#       macro avg       0.70      0.70      0.70    253703
#    weighted avg       0.73      0.74      0.73    253703
#
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 11.39 +- 16.24
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# MSE auf als informativ klassifizierten Segmenten: 393.60
# MSE auf als informativ annotierten Segmenten:  5.68
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 31.51 %
# Coverage annotiert          : 32.61 %
#
# ...

# %%
display(Markdown("## RF_Clf_h5"))
models_rf_clf['RF_Clf_s10_default_h5'].print_model_test_report()
display(Markdown("## RF_Clf_h20"))
models_rf_clf['RF_Clf_s10_default_h20'].print_model_test_report()
# Out:
# ## RF_Clf_h5
# AUC: 0.78
# F1-Score: 0.59
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.80      0.83      0.81    170982
#     informative       0.62      0.56      0.59     82721
#
#        accuracy                           0.74    253703
#       macro avg       0.71      0.70      0.70    253703
#    weighted avg       0.74      0.74      0.74    253703
#
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 11.39 +- 16.86
# MAE auf als informativ annotierten Segmenten:  1.98 +- 1.33
# MSE auf als informativ klassifizierten Segmenten: 413.97
# MSE auf als informativ annotierten Segmenten:  5.68
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 29.30 %
# Coverage annotiert          : 32.61 %
#
# ...
