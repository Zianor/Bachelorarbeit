# %%
from estimators import OwnEstimator
from own_models_train import get_default_results
from IPython.display import display, Markdown

paths = ["RF_Clf_default", "RF_Regr_default", "XGB_Regr_default", "XGB_Clf_default"]
feature_selection = [
        'mean',
        'number_zero_crossings',
        'kurtosis',
        'skewness',
        'hf_diff_acf',
        'hf_diff_data',
        'interval_lengths_std',
        'sqi_std',
        'sqi_min',
        'sqi_median',
        'peak_mean',
        'peak_std',
        'template_corr_highest_sqi_mean',
        'template_corr_highest_sqi_std',
        'template_corr_median_sqi_mean',
        'template_corr_median_sqi_std',
        'interval_means_std',
        'sqi_coverage_03',
        'sqi_coverage_04',
        'sqi_coverage_05'
    ]

# %%
models = {
    "RF_Clf_default": None, "RF_Regr_default": None, "XGB_Regr_default": None, "XGB_Clf_default": None}
for path in paths:
    est = OwnEstimator(clf=None, path=path, feature_selection=feature_selection, segment_length=10, overlap_amount=0.9,
                 hr_threshold=10, data_folder='data_patients')
    models[path] = est

    # get_default_results()

# %%
display(Markdown("# RF_Clf_default"))
models["RF_Clf_default"].print_model_test_report()
# Out:
# # RF_Clf_default
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    9.2s finished
# AUC: 0.69
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    9.0s finished
# F1-Score: 0.54
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.66      0.79      0.72    144087
#     informative       0.63      0.48      0.54    109616
#
#        accuracy                           0.65    253703
#       macro avg       0.65      0.63      0.63    253703
#    weighted avg       0.65      0.65      0.64    253703
#
# MAE auf als informativ klassifizierten Segmenten: 13.90
# MAE auf als informativ annotierten Segmenten:  3.28
# ...

# %%
display(Markdown("# RF_Regr_default"))
models["RF_Regr_default"].print_model_test_report()
# Out:
# # RF_Regr_default
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    7.9s finished
# AUC: 0.67
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    7.1s finished
# F1-Score: 0.34
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.62      0.95      0.75    144087
#     informative       0.76      0.22      0.34    109616
#
#        accuracy                           0.63    253703
#       macro avg       0.69      0.58      0.54    253703
#    weighted avg       0.68      0.63      0.57    253703
#
# MAE auf als informativ klassifizierten Segmenten: 8.83
# MAE auf als informativ annotierten Segmenten:  3.28
# ...

# %%
display(Markdown("# XGB_Clf_default"))
models["XGB_Clf_default"].print_model_test_report()
# Out:
# # XGB_Clf_default
# AUC: 0.68
# F1-Score: 0.57
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.67      0.70      0.69    144087
#     informative       0.58      0.55      0.57    109616
#
#        accuracy                           0.64    253703
#       macro avg       0.63      0.63      0.63    253703
#    weighted avg       0.63      0.64      0.64    253703
#
# MAE auf als informativ klassifizierten Segmenten: 14.84
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 592.64
# MSE auf als informativ annotierten Segmenten:  17.80
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 40.97 %
# Coverage annotiert          : 43.21 %
#
# ...

# %%
display(Markdown("# XGB_Regr_default"))
models["XGB_Regr_default"].print_model_test_report()
# Out:
# # XGB_Regr_default
# AUC: 0.65
# F1-Score: 0.44
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.63      0.85      0.72    144087
#     informative       0.63      0.34      0.44    109616
#
#        accuracy                           0.63    253703
#       macro avg       0.63      0.59      0.58    253703
#    weighted avg       0.63      0.63      0.60    253703
#
# MAE auf als informativ klassifizierten Segmenten: 12.63
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 433.80
# MSE auf als informativ annotierten Segmenten:  17.80
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 23.12 %
# Coverage annotiert          : 43.21 %
#
# ...
