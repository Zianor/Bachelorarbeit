# %%
from own_models_train import get_paths
from estimators import *
from IPython.display import display, Markdown

# %%
get_paths(reduced=False, segment_length=10, threshold=10)
# Out:
# ['RF_Clf_s10_all_10',
#  'RF_Regr_s10_all_10',
#  'XGB_Regr_s10_all_10',
#  'XGB_Clf_s10_all_10']

# %%
models = {
    'RF_Clf_s10_all_10': None,
    'RF_Regr_s10_all_10': None,
    'XGB_Regr_s10_all_10': None,
    'XGB_Clf_s10_all_10': None
}

# %%
for path in models.keys():
    models[path] = OwnEstimator(clf=None, path=path)

# %%
display(Markdown("# RF_Clf_s10_all_10"))
models['RF_Clf_s10_all_10'].print_model_test_report()
# Out:
# # RF_Clf_s10_all_10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    6.2s finished
# AUC: 0.75
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 200 out of 200 | elapsed:    6.1s finished
# F1-Score: 0.60
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.70      0.80      0.74    144087
#     informative       0.67      0.54      0.60    109616
#
#        accuracy                           0.69    253703
#       macro avg       0.69      0.67      0.67    253703
#    weighted avg       0.69      0.69      0.68    253703
#
# MAE auf als informativ klassifizierten Segmenten: 11.88
# ...

# %%
display(Markdown("# RF_Regr_s10_all_10"))
models['RF_Regr_s10_all_10'].print_model_test_report()
# Out:
# # RF_Regr_s10_all_10
# AUC: 0.74
# F1-Score: 0.44
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.64      0.93      0.75    144087
#     informative       0.76      0.31      0.44    109616
#
#        accuracy                           0.66    253703
#       macro avg       0.70      0.62      0.59    253703
#    weighted avg       0.69      0.66      0.62    253703
#
# MAE auf als informativ klassifizierten Segmenten: 8.91
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 273.07
# MSE auf als informativ annotierten Segmenten:  17.80
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 17.38 %
# Coverage annotiert          : 43.21 %
#
# ...

# %%
display(Markdown("# XGB_Regr_s10_all_10"))
models['XGB_Regr_s10_all_10'].print_model_test_report()
# Out:
# # XGB_Regr_s10_all_10
# AUC: 0.73
# F1-Score: 0.55
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.67      0.83      0.74    144087
#     informative       0.67      0.47      0.55    109616
#
#        accuracy                           0.67    253703
#       macro avg       0.67      0.65      0.65    253703
#    weighted avg       0.67      0.67      0.66    253703
#
# MAE auf als informativ klassifizierten Segmenten: 10.71
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 313.32
# MSE auf als informativ annotierten Segmenten:  17.80
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 30.30 %
# Coverage annotiert          : 43.21 %
#
# ...

# %%
display(Markdown("# XGB_Clf_s10_all_10"))
models['XGB_Clf_s10_all_10'].print_model_test_report()
# Out:
# # XGB_Clf_s10_all_10
# AUC: 0.76
# F1-Score: 0.64
#
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.73      0.74      0.73    144087
#     informative       0.65      0.63      0.64    109616
#
#        accuracy                           0.69    253703
#       macro avg       0.69      0.69      0.69    253703
#    weighted avg       0.69      0.69      0.69    253703
#
# MAE auf als informativ klassifizierten Segmenten: 11.96
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 389.15
# MSE auf als informativ annotierten Segmenten:  17.80
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 41.89 %
# Coverage annotiert          : 43.21 %
#
# ...
