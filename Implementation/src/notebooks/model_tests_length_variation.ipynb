# %%
from own_models_train import get_final_paths, get_final_column_names
from eda_utils import get_latex_column_names
import utils
from estimators import *
from IPython.display import display, Markdown

plt.rcParams.update(utils.get_plt_settings())

# %%
models_rf_clf = {
    'RF_Clf_s5_default_h20': None,
    'RF_Clf_s10_default_h20': None,
    'RF_Clf_s20_default_h20': None,
    'RF_Clf_s30_default_h20': None
}
segment_lengths = [5, 10, 20, 30]
overlap_amounts = [0.8, 0.9, 0.9, 0.9]
for i, path in enumerate(models_rf_clf.keys()):
    print(path)
    segment_length = segment_lengths[i]
    overlap_amount = overlap_amounts[i]
    feature_selection = get_final_column_names()
    models_rf_clf[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection,
                                       segment_length=segment_length, overlap_amount=overlap_amount, hr_threshold=20)
# Out:
# RF_Clf_s5_default_h20
# RF_Clf_s10_default_h20
# RF_Clf_s20_default_h20
# RF_Clf_s30_default_h20

# %%
display(Markdown("## RF_Clf_s5"))
models_rf_clf['RF_Clf_s5_default_h20'].print_short_report()
display(Markdown("## RF_Clf_s10"))
models_rf_clf['RF_Clf_s10_default_h20'].print_short_report()
display(Markdown("## RF_Clf_s20"))
models_rf_clf['RF_Clf_s20_default_h20'].print_short_report()
display(Markdown("## RF_Clf_s30"))
models_rf_clf['RF_Clf_s30_default_h20'].print_short_report()
# Out:
# ## RF_Clf_s5
# AUC: 0.74
# F1: 0.66
# Coverage klassifiziert      : 45.94 %
# Coverage annotiert          : 55.22 %
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 14.20 +- 17.96
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# ## RF_Clf_s10
# AUC: 0.73
# F1: 0.70
# Coverage klassifiziert      : 53.78 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 13.27 +- 15.83
# MAE auf als informativ annotierten Segmenten:  6.45 +- 5.84
# ## RF_Clf_s20
# AUC: 0.73
# F1: 0.74
# Coverage klassifiziert      : 60.93 %
# Coverage annotiert          : 62.02 %
# MAE insgesamt:  19.99 +- 28.91
# MAE auf als informativ klassifizierten Segmenten: 13.03 +- 14.76
# MAE auf als informativ annotierten Segmenten:  6.50 +- 5.72
# ## RF_Clf_s30
# AUC: 0.73
# F1: 0.75
# Coverage klassifiziert      : 62.01 %
# Coverage annotiert          : 62.92 %
# MAE insgesamt:  19.31 +- 28.52
# ...

# %%
models_xgb_clf = {
    'XGB_Clf_s5_default_h20': None,
    'XGB_Clf_s10_default_h20': None,
    'XGB_Clf_s20_default_h20': None,
    'XGB_Clf_s30_default_h20': None
}
segment_lengths = [5, 10, 20, 30]
overlap_amounts = [0.8, 0.9, 0.9, 0.9]
for i, path in enumerate(models_xgb_clf.keys()):
    print(path)
    segment_length = segment_lengths[i]
    overlap_amount = overlap_amounts[i]
    feature_selection = get_final_column_names()
    models_xgb_clf[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection,
                                       segment_length=segment_length, overlap_amount=overlap_amount, hr_threshold=20)
# Out:
# XGB_Clf_s5_default_h20
# XGB_Clf_s10_default_h20
# XGB_Clf_s20_default_h20
# XGB_Clf_s30_default_h20

# %%
display(Markdown("## XGB_Clf_s5"))
models_xgb_clf['XGB_Clf_s5_default_h20'].print_short_report()
display(Markdown("## XGB_Clf_s10"))
models_xgb_clf['XGB_Clf_s10_default_h20'].print_short_report()
display(Markdown("## XGB_Clf_s20"))
models_xgb_clf['XGB_Clf_s20_default_h20'].print_short_report()
display(Markdown("## XGB_Clf_s30"))
models_xgb_clf['XGB_Clf_s30_default_h20'].print_short_report()
# Out:
# ## XGB_Clf_s5
# AUC: 0.74
# F1: 0.69
# Coverage klassifiziert      : 53.18 %
# Coverage annotiert          : 55.22 %
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 14.89 +- 17.06
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# ## XGB_Clf_s10
# AUC: 0.73
# F1: 0.73
# Coverage klassifiziert      : 59.73 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 13.86 +- 15.75
# MAE auf als informativ annotierten Segmenten:  6.45 +- 5.84
# ## XGB_Clf_s20
# AUC: 0.73
# F1: 0.76
# Coverage klassifiziert      : 64.81 %
# Coverage annotiert          : 62.02 %
# MAE insgesamt:  19.99 +- 28.91
# MAE auf als informativ klassifizierten Segmenten: 13.23 +- 14.58
# MAE auf als informativ annotierten Segmenten:  6.50 +- 5.72
# ## XGB_Clf_s30
# AUC: 0.73
# F1: 0.77
# Coverage klassifiziert      : 67.00 %
# Coverage annotiert          : 62.92 %
# MAE insgesamt:  19.31 +- 28.52
# ...

# %%
models_rf_regr = {
    'RF_Regr_s5_default_h20': None,
    'RF_Regr_s10_default_h20': None,
    'RF_Regr_s20_default_h20': None,
    'RF_Regr_s30_default_h20': None
}
segment_lengths = [5, 10, 20, 30]
overlap_amounts = [0.8, 0.9, 0.9, 0.9]
for i, path in enumerate(models_rf_regr.keys()):
    print(path)
    segment_length = segment_lengths[i]
    overlap_amount = overlap_amounts[i]
    feature_selection = get_final_column_names()
    models_rf_regr[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection,
                                       segment_length=segment_length, overlap_amount=overlap_amount, hr_threshold=20)
# Out:
# RF_Regr_s5_default_h20
# RF_Regr_s10_default_h20
# RF_Regr_s20_default_h20
# RF_Regr_s30_default_h20

# %%
display(Markdown("## RF_Regr_s5"))
models_rf_regr['RF_Regr_s5_default_h20'].print_short_report()
display(Markdown("## RF_Regr_s10"))
models_rf_regr['RF_Regr_s10_default_h20'].print_short_report()
display(Markdown("## RF_Regr_s20"))
models_rf_regr['RF_Regr_s20_default_h20'].print_short_report()
display(Markdown("## RF_Regr_s30"))
models_rf_regr['RF_Regr_s30_default_h20'].print_short_report()
# Out:
# ## RF_Regr_s5
# AUC: 0.74
# F1: 0.75
# Coverage klassifiziert      : 78.93 %
# Coverage annotiert          : 55.22 %
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 17.62 +- 19.13
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# ## RF_Regr_s10
# AUC: 0.73
# F1: 0.78
# Coverage klassifiziert      : 79.47 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 15.39 +- 16.50
# MAE auf als informativ annotierten Segmenten:  6.45 +- 5.84
# ## RF_Regr_s20
# AUC: 0.73
# F1: 0.80
# Coverage klassifiziert      : 80.15 %
# Coverage annotiert          : 62.02 %
# MAE insgesamt:  19.99 +- 28.91
# MAE auf als informativ klassifizierten Segmenten: 14.35 +- 15.22
# MAE auf als informativ annotierten Segmenten:  6.50 +- 5.72
# ## RF_Regr_s30
# AUC: 0.73
# F1: 0.81
# Coverage klassifiziert      : 80.31 %
# Coverage annotiert          : 62.92 %
# MAE insgesamt:  19.31 +- 28.52
# ...

# %%
models_xgb_regr = {
    'XGB_Regr_s5_default_h20': None,
    'XGB_Regr_s10_default_h20': None,
    'XGB_Regr_s20_default_h20': None,
    'XGB_Regr_s30_default_h20': None
}
segment_lengths = [5, 10, 20, 30]
overlap_amounts = [0.8, 0.9, 0.9, 0.9]
for i, path in enumerate(models_xgb_regr.keys()):
    print(path)
    segment_length = segment_lengths[i]
    overlap_amount = overlap_amounts[i]
    feature_selection = get_final_column_names()
    models_xgb_regr[path] = OwnEstimator(clf=None, path=path, feature_selection=feature_selection,
                                       segment_length=segment_length, overlap_amount=overlap_amount, hr_threshold=20)
# Out:
# XGB_Regr_s5_default_h20
# XGB_Regr_s10_default_h20
# XGB_Regr_s20_default_h20
# XGB_Regr_s30_default_h20

# %%
display(Markdown("## XGB_Regr_s5"))
models_xgb_regr['XGB_Regr_s5_default_h20'].print_short_report()
display(Markdown("## XGB_Regr_s10"))
models_xgb_regr['XGB_Regr_s10_default_h20'].print_short_report()
display(Markdown("## XGB_Regr_s20"))
models_xgb_regr['XGB_Regr_s20_default_h20'].print_short_report()
display(Markdown("## XGB_Regr_s30"))
models_xgb_regr['XGB_Regr_s30_default_h20'].print_short_report()
# Out:
# ## XGB_Regr_s5
# AUC: 0.74
# F1: 0.74
# Coverage klassifiziert      : 69.40 %
# Coverage annotiert          : 55.22 %
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 16.34 +- 17.67
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# ## XGB_Regr_s10
# AUC: 0.73
# F1: 0.77
# Coverage klassifiziert      : 74.18 %
# Coverage annotiert          : 59.45 %
# MAE insgesamt:  21.85 +- 30.48
# MAE auf als informativ klassifizierten Segmenten: 14.94 +- 16.13
# MAE auf als informativ annotierten Segmenten:  6.45 +- 5.84
# ## XGB_Regr_s20
# AUC: 0.72
# F1: 0.79
# Coverage klassifiziert      : 76.69 %
# Coverage annotiert          : 62.02 %
# MAE insgesamt:  19.99 +- 28.91
# MAE auf als informativ klassifizierten Segmenten: 14.17 +- 15.24
# MAE auf als informativ annotierten Segmenten:  6.50 +- 5.72
# ## XGB_Regr_s30
# AUC: 0.71
# F1: 0.80
# Coverage klassifiziert      : 77.14 %
# Coverage annotiert          : 62.92 %
# ...

# %%
display(Markdown("## RF_Clf_s5"))
models_rf_clf['RF_Clf_s5_default_h20'].print_model_test_report()
display(Markdown("## RF_Clf_s30"))
models_rf_clf['RF_Clf_s30_default_h20'].print_model_test_report()
# Out:
# ## RF_Clf_s5
# AUC: 0.74
# F1-Score: 0.66
#
#  Testset insgesamt
# Fehler < 5 FE   : 29.88 %
# Fehler < 10 FE   : 39.29 %
# Fehler < 15 FE   : 47.38 %
# Fehler < 20 FE   : 55.15 %
# Fehler = 667 FE : 0.24398 %
#                  precision    recall  f1-score   support
#
# non-informative       0.60      0.72      0.65    113620
#     informative       0.73      0.61      0.66    140090
#
#        accuracy                           0.66    253710
#       macro avg       0.66      0.66      0.66    253710
#    weighted avg       0.67      0.66      0.66    253710
#
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 14.20 +- 17.96
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# MSE auf als informativ klassifizierten Segmenten: 524.16
# MSE auf als informativ annotierten Segmenten:  79.28
# MSE insgesamt:  2404.81
#
#
# Coverage klassifiziert      : 45.94 %
# Coverage annotiert          : 55.22 %
#
# ...

# %%
display(Markdown("## RF_Regr_s5"))
models_rf_regr['RF_Regr_s5_default_h20'].print_model_test_report("rf-regr-s5-h20")
display(Markdown("## RF_Regr_s30"))
models_rf_regr['RF_Regr_s30_default_h20'].print_model_test_report("rf-regr-s30-h20")
# Out:
# ## RF_Regr_s5
# AUC: 0.74
# F1-Score: 0.75
#
#  Testset insgesamt
# Fehler < 5 FE   : 29.88 %
# Fehler < 10 FE   : 39.29 %
# Fehler < 15 FE   : 47.38 %
# Fehler < 20 FE   : 55.15 %
# Fehler = 667 FE : 0.24398 %
#                  precision    recall  f1-score   support
#
# non-informative       0.78      0.37      0.50    113620
#     informative       0.64      0.92      0.75    140090
#
#        accuracy                           0.67    253710
#       macro avg       0.71      0.64      0.63    253710
#    weighted avg       0.70      0.67      0.64    253710
#
# MAE insgesamt:  25.95 +- 41.61
# MAE auf als informativ klassifizierten Segmenten: 17.62 +- 19.13
# MAE auf als informativ annotierten Segmenten:  6.59 +- 5.99
# MSE auf als informativ klassifizierten Segmenten: 676.64
# MSE auf als informativ annotierten Segmenten:  79.28
# MSE insgesamt:  2404.81
#
#
# Coverage klassifiziert      : 78.93 %
# Coverage annotiert          : 55.22 %
#
# ...
