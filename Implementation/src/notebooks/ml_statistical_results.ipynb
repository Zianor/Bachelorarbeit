# %%
import estimators
import utils

import seaborn as sn
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

plt.rcParams.update(utils.get_plt_settings())

# %% [markdown]
# # LDA Paper

# %%
lda = estimators.MLStatisticalEstimator("LDA_hr10")

lda.print_model_test_report()
# Out:
#  Testset insgesamt
# Fehler < 5    : 32.61 %
# Fehler < 10   : 43.21 %
# Fehler < 15   : 51.64 %
# Fehler < 20   : 59.38 %
# Fehler = 667  : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.68      0.18      0.29    144049
#     informative       0.45      0.89      0.60    109654
#
#        accuracy                           0.49    253703
#       macro avg       0.57      0.53      0.44    253703
#    weighted avg       0.58      0.49      0.42    253703
#
# MAE auf als informativ klassifizierten Segmenten: 21.84
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 1498.46
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 84.81 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 32.61 %
# Fehler < 5 klassifiziert    : 29.64 %
# Fehler < 10 gesamt          : 43.21 %
# Fehler < 10 klassifiziert   : 38.34 %
# Fehler < 15 gesamt          : 51.64 %
# Fehler < 15 klassifiziert   : 44.96 %
# Fehler < 20 gesamt          : 59.38 %
# Fehler < 20 klassifiziert   : 51.00 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.09499 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5    : 34.95 %
# Fehler < 10   : 45.20 %
# Fehler < 15   : 53.01 %
# Fehler < 20   : 60.13 %
# Fehler = 667  : 0.11200 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 37.27
# Fehler < 5    : 0.00 %
# Fehler < 10   : 0.00 %
# Fehler < 15   : 14.23 %
# Fehler < 20   : 27.22 %
# Fehler = 667  : 0.20443 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.28
# Fehler < 5    : 60.85 %
# Fehler < 10   : 99.89 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # Random Forest Paper

# %%
rf = estimators.MLStatisticalEstimator("RF_hr10")

rf.print_model_test_report("rf-statistical")
# Out:
#  Testset insgesamt
# Fehler < 5    : 32.61 %
# Fehler < 10   : 43.21 %
# Fehler < 15   : 51.64 %
# Fehler < 20   : 59.38 %
# Fehler = 667  : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.62      0.61      0.62    144049
#     informative       0.50      0.51      0.51    109654
#
#        accuracy                           0.57    253703
#       macro avg       0.56      0.56      0.56    253703
#    weighted avg       0.57      0.57      0.57    253703
#
# MAE auf als informativ klassifizierten Segmenten: 17.66
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 763.23
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 44.20 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 32.61 %
# Fehler < 5 klassifiziert    : 17.35 %
# Fehler < 10 gesamt          : 43.21 %
# Fehler < 10 klassifiziert   : 22.20 %
# Fehler < 15 gesamt          : 51.64 %
# Fehler < 15 klassifiziert   : 25.92 %
# Fehler < 20 gesamt          : 59.38 %
# Fehler < 20 klassifiziert   : 29.23 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00276 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5    : 39.26 %
# Fehler < 10   : 50.23 %
# Fehler < 15   : 58.64 %
# Fehler < 20   : 66.14 %
# Fehler = 667  : 0.00624 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 32.37
# Fehler < 5    : 0.00 %
# Fehler < 10   : 0.00 %
# Fehler < 15   : 16.88 %
# Fehler < 20   : 31.94 %
# Fehler = 667  : 0.01255 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.48
# Fehler < 5    : 72.57 %
# Fehler < 10   : 99.96 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # Decision Tree Paper

# %%
dt = estimators.MLStatisticalEstimator("DT_hr10")

dt.print_model_test_report()
# Out:
#  Testset insgesamt
# Fehler < 5    : 32.61 %
# Fehler < 10   : 43.21 %
# Fehler < 15   : 51.64 %
# Fehler < 20   : 59.38 %
# Fehler = 667  : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.60      0.56      0.58    144049
#     informative       0.47      0.51      0.49    109654
#
#        accuracy                           0.53    253703
#       macro avg       0.53      0.53      0.53    253703
#    weighted avg       0.54      0.53      0.54    253703
#
# MAE auf als informativ klassifizierten Segmenten: 19.39
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 875.27
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 47.20 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 32.61 %
# Fehler < 5 klassifiziert    : 16.84 %
# Fehler < 10 gesamt          : 43.21 %
# Fehler < 10 klassifiziert   : 21.95 %
# Fehler < 15 gesamt          : 51.64 %
# Fehler < 15 klassifiziert   : 25.97 %
# Fehler < 20 gesamt          : 59.38 %
# Fehler < 20 klassifiziert   : 29.63 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00276 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5    : 35.68 %
# Fehler < 10   : 46.51 %
# Fehler < 15   : 55.02 %
# Fehler < 20   : 62.77 %
# Fehler = 667  : 0.00585 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 33.49
# Fehler < 5    : 0.00 %
# Fehler < 10   : 0.00 %
# Fehler < 15   : 15.89 %
# Fehler < 20   : 30.37 %
# Fehler = 667  : 0.01093 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.37
# Fehler < 5    : 74.15 %
# Fehler < 10   : 99.97 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # MLP Paper

# %%
mlp = estimators.MLStatisticalEstimator("MLP_hr10")

mlp.print_model_test_report("mlp-statistical")
# Out:
#  Testset insgesamt
# Fehler < 5    : 32.61 %
# Fehler < 10   : 43.21 %
# Fehler < 15   : 51.64 %
# Fehler < 20   : 59.38 %
# Fehler = 667  : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.61      0.63      0.62    144049
#     informative       0.50      0.48      0.49    109654
#
#        accuracy                           0.56    253703
#       macro avg       0.55      0.55      0.55    253703
#    weighted avg       0.56      0.56      0.56    253703
#
# MAE auf als informativ klassifizierten Segmenten: 18.41
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 800.14
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 42.04 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 32.61 %
# Fehler < 5 klassifiziert    : 16.07 %
# Fehler < 10 gesamt          : 43.21 %
# Fehler < 10 klassifiziert   : 20.82 %
# Fehler < 15 gesamt          : 51.64 %
# Fehler < 15 klassifiziert   : 24.34 %
# Fehler < 20 gesamt          : 59.38 %
# Fehler < 20 klassifiziert   : 27.45 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00000 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5    : 38.22 %
# Fehler < 10   : 49.51 %
# Fehler < 15   : 57.89 %
# Fehler < 20   : 65.29 %
# Fehler = 667  : 0.00000 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 33.37
# Fehler < 5    : 0.00 %
# Fehler < 10   : 0.00 %
# Fehler < 15   : 16.59 %
# Fehler < 20   : 31.23 %
# Fehler = 667  : 0.00000 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.39
# Fehler < 5    : 73.83 %
# Fehler < 10   : 99.96 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # SVC Paper

# %%
svc = estimators.MLStatisticalEstimator("SVC_hr10")

svc.print_model_test_report()
# Out:
#  Testset insgesamt
# Fehler < 5    : 32.61 %
# Fehler < 10   : 43.21 %
# Fehler < 15   : 51.64 %
# Fehler < 20   : 59.38 %
# Fehler = 667  : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.68      0.14      0.23    144049
#     informative       0.45      0.91      0.60    109654
#
#        accuracy                           0.47    253703
#       macro avg       0.56      0.53      0.42    253703
#    weighted avg       0.58      0.47      0.39    253703
#
# MAE auf als informativ klassifizierten Segmenten: 22.06
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 1496.79
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 88.14 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 32.61 %
# Fehler < 5 klassifiziert    : 30.36 %
# Fehler < 10 gesamt          : 43.21 %
# Fehler < 10 klassifiziert   : 39.39 %
# Fehler < 15 gesamt          : 51.64 %
# Fehler < 15 klassifiziert   : 46.31 %
# Fehler < 20 gesamt          : 59.38 %
# Fehler < 20 klassifiziert   : 52.64 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.09499 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5    : 34.45 %
# Fehler < 10   : 44.69 %
# Fehler < 15   : 52.54 %
# Fehler < 20   : 59.72 %
# Fehler = 667  : 0.10777 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 37.33
# Fehler < 5    : 0.00 %
# Fehler < 10   : 0.00 %
# Fehler < 15   : 14.17 %
# Fehler < 20   : 27.15 %
# Fehler = 667  : 0.19490 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.43
# Fehler < 5    : 58.70 %
# Fehler < 10   : 99.88 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %
