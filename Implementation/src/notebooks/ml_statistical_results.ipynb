# %%
import estimators
import utils

import seaborn as sn
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

plt.rcParams.update(utils.get_plt_settings())

save=True

# %% [markdown]
# # LDA Paper

# %%
lda = estimators.MLStatisticalEstimator("LDA_hr10")
y_pred, y_true = lda.predict_test_set()

class_names = ['non-informative', 'informative']
coverage = len(y_pred[y_pred])/len(y_true.index)*100
coverage_annotated = len(y_true[y_true])/len(y_true.index)*100

ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred), display_labels=class_names).plot()
print(classification_report(y_true, y_pred, target_names=class_names))
lda.print_model_test_report()
# Out:
#                  precision    recall  f1-score   support
#
# non-informative       0.68      0.18      0.29    144049
#     informative       0.45      0.89      0.60    109654
#
#        accuracy                           0.49    253703
#       macro avg       0.57      0.53      0.44    253703
#    weighted avg       0.58      0.49      0.42    253703
#
# MAE auf als informativ klassifizierten Segmenten: 20.60
# MAE auf als informativ annotierten Segmenten:  20.78
# MSE auf als informativ klassifizierten Segmenten: 1415.13
# MAE auf als informativ annotierten Segmenten:  1334.28
#
#
# Coverage klassifiziert      : 84.82 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 33.60 %
# Fehler < 5 klassifiziert    : 30.62 %
# Fehler < 10 gesamt          : 44.74 %
# Fehler < 10 klassifiziert   : 39.87 %
# Fehler < 15 gesamt          : 53.94 %
# Fehler < 15 klassifiziert   : 47.25 %
# Fehler < 20 gesamt          : 61.86 %
# Fehler < 20 klassifiziert   : 53.45 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.09499 %
#
#  Coverage bestimmter Fehler auf informativem Signal
# Fehler < 5    : 36.10 %
# Fehler < 10   : 47.00 %
# Fehler < 15   : 55.71 %
# Fehler < 20   : 63.02 %
# Fehler = 667  : 0.11200 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 35.09 %
# Fehler < 5    : 0.97 %
# Fehler < 10   : 3.29 %
# Fehler < 15   : 19.16 %
# Fehler < 20   : 32.51 %
# Fehler = 667  : 0.20443 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.27 %
# Fehler < 5    : 60.92 %
# Fehler < 10   : 99.89 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # Random Forest Paper

# %%
rf = estimators.MLStatisticalEstimator("RF_hr10")
y_pred, y_true = rf.predict_test_set()

class_names = ['non-informative', 'informative']
coverage = len(y_pred[y_pred])/len(y_true.index)*100
coverage_annotated = len(y_true[y_true])/len(y_true.index)*100

ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred), display_labels=class_names).plot()
print(classification_report(y_true, y_pred, target_names=class_names))
rf.print_model_test_report()
# Out:
#                  precision    recall  f1-score   support
#
# non-informative       0.62      0.63      0.63    144049
#     informative       0.51      0.50      0.50    109654
#
#        accuracy                           0.57    253703
#       macro avg       0.57      0.56      0.56    253703
#    weighted avg       0.57      0.57      0.57    253703
#
# MAE auf als informativ klassifizierten Segmenten: 16.23
# MAE auf als informativ annotierten Segmenten:  20.78
# MSE auf als informativ klassifizierten Segmenten: 663.30
# MAE auf als informativ annotierten Segmenten:  1334.28
#
#
# Coverage klassifiziert      : 42.69 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 33.60 %
# Fehler < 5 klassifiziert    : 17.45 %
# Fehler < 10 gesamt          : 44.74 %
# Fehler < 10 klassifiziert   : 22.35 %
# Fehler < 15 gesamt          : 53.94 %
# Fehler < 15 klassifiziert   : 26.28 %
# Fehler < 20 gesamt          : 61.86 %
# Fehler < 20 klassifiziert   : 29.58 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00236 %
#
#  Coverage bestimmter Fehler auf informativem Signal
# Fehler < 5    : 40.87 %
# Fehler < 10   : 52.36 %
# Fehler < 15   : 61.57 %
# Fehler < 20   : 69.29 %
# Fehler = 667  : 0.00554 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 29.86 %
# Fehler < 5    : 1.09 %
# Fehler < 10   : 3.44 %
# Fehler < 15   : 22.08 %
# Fehler < 20   : 37.73 %
# Fehler = 667  : 0.01123 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.39 %
# Fehler < 5    : 73.75 %
# Fehler < 10   : 99.96 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # Decision Tree Paper

# %%
dt = estimators.MLStatisticalEstimator("DT_hr10")
y_pred, y_true = dt.predict_test_set()

class_names = ['non-informative', 'informative']
coverage = len(y_pred[y_pred])/len(y_true.index)*100
coverage_annotated = len(y_true[y_true])/len(y_true.index)*100

ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred), display_labels=class_names).plot()
print(classification_report(y_true, y_pred, target_names=class_names))
dt.print_model_test_report()
# Out:
#                  precision    recall  f1-score   support
#
# non-informative       0.60      0.56      0.58    144049
#     informative       0.47      0.51      0.49    109654
#
#        accuracy                           0.54    253703
#       macro avg       0.53      0.53      0.53    253703
#    weighted avg       0.54      0.54      0.54    253703
#
# MAE auf als informativ klassifizierten Segmenten: 18.25
# MAE auf als informativ annotierten Segmenten:  20.78
# MSE auf als informativ klassifizierten Segmenten: 799.80
# MAE auf als informativ annotierten Segmenten:  1334.28
#
#
# Coverage klassifiziert      : 47.04 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 33.60 %
# Fehler < 5 klassifiziert    : 17.42 %
# Fehler < 10 gesamt          : 44.74 %
# Fehler < 10 klassifiziert   : 22.76 %
# Fehler < 15 gesamt          : 53.94 %
# Fehler < 15 klassifiziert   : 27.12 %
# Fehler < 20 gesamt          : 61.86 %
# Fehler < 20 klassifiziert   : 30.82 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00236 %
#
#  Coverage bestimmter Fehler auf informativem Signal
# Fehler < 5    : 37.03 %
# Fehler < 10   : 48.39 %
# Fehler < 15   : 57.64 %
# Fehler < 20   : 65.51 %
# Fehler = 667  : 0.00503 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 31.58 %
# Fehler < 5    : 0.92 %
# Fehler < 10   : 3.12 %
# Fehler < 15   : 20.46 %
# Fehler < 20   : 35.24 %
# Fehler = 667  : 0.00944 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.29 %
# Fehler < 5    : 75.13 %
# Fehler < 10   : 99.97 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %

# %% [markdown]
# # MLP Paper

# %%
mlp = estimators.MLStatisticalEstimator("MLP_hr10")
y_pred, y_true = mlp.predict_test_set()

class_names = ['non-informative', 'informative']
coverage = len(y_pred[y_pred])/len(y_true.index)*100
coverage_annotated = len(y_true[y_true])/len(y_true.index)*100

ConfusionMatrixDisplay(confusion_matrix(y_true, y_pred), display_labels=class_names).plot()
print(classification_report(y_true, y_pred, target_names=class_names))
mlp.print_model_test_report()
# Out:
#                  precision    recall  f1-score   support
#
# non-informative       0.62      0.57      0.59    144049
#     informative       0.49      0.54      0.51    109654
#
#        accuracy                           0.55    253703
#       macro avg       0.55      0.55      0.55    253703
#    weighted avg       0.56      0.55      0.56    253703
#
# MAE auf als informativ klassifizierten Segmenten: 17.58
# MAE auf als informativ annotierten Segmenten:  20.78
# MSE auf als informativ klassifizierten Segmenten: 735.17
# MAE auf als informativ annotierten Segmenten:  1334.28
#
#
# Coverage klassifiziert      : 47.68 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 gesamt           : 33.60 %
# Fehler < 5 klassifiziert    : 18.26 %
# Fehler < 10 gesamt          : 44.74 %
# Fehler < 10 klassifiziert   : 23.82 %
# Fehler < 15 gesamt          : 53.94 %
# Fehler < 15 klassifiziert   : 28.23 %
# Fehler < 20 gesamt          : 61.86 %
# Fehler < 20 klassifiziert   : 31.95 %
# Fehler = 667 gesamt         : 0.09578 %
# Fehler = 667 klassifiziert  : 0.00000 %
#
#  Coverage bestimmter Fehler auf informativem Signal
# Fehler < 5    : 38.31 %
# Fehler < 10   : 49.96 %
# Fehler < 15   : 59.20 %
# Fehler < 20   : 67.00 %
# Fehler = 667  : 0.00000 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 31.26 %
# Fehler < 5    : 0.85 %
# Fehler < 10   : 2.72 %
# Fehler < 15   : 20.66 %
# Fehler < 20   : 35.83 %
# Fehler = 667  : 0.00000 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.28 %
# Fehler < 5    : 75.19 %
# Fehler < 10   : 99.96 %
# Fehler < 15   : 100.00 %
# Fehler < 20   : 100.00 %
# Fehler = 667  : 0.00000 %
