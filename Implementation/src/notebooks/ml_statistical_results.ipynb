# %%
import estimators
import utils

import seaborn as sn
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

plt.rcParams.update(utils.get_plt_settings())

# %% [markdown]
# # LDA Paper

# %%
lda = estimators.MLStatisticalEstimator("LDA_hr10")

lda.print_model_test_report()
# Out:
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearDiscriminantAnalysis from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomizedSearchCV from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.68      0.18      0.29    144049
#     informative       0.45      0.89      0.60    109654
#
#        accuracy                           0.49    253703
#       macro avg       0.57      0.53      0.44    253703
#    weighted avg       0.58      0.49      0.42    253703
#
# MAE auf als informativ klassifizierten Segmenten: 21.84
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 1498.46
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 84.81 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 FE gesamt           : 32.61 %
# Fehler < 5 FE klassifiziert    : 29.64 %
# Fehler < 10 FE gesamt          : 43.21 %
# Fehler < 10 FE klassifiziert   : 38.34 %
# Fehler < 15 FE gesamt          : 51.64 %
# Fehler < 15 FE klassifiziert   : 44.96 %
# Fehler < 20 FE gesamt          : 59.38 %
# Fehler < 20 FE klassifiziert   : 51.00 %
# Fehler = 667 FE gesamt         : 0.09578 %
# Fehler = 667 FE klassifiziert  : 0.09499 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5 FE   : 34.95 %
# Fehler < 10 FE   : 45.20 %
# Fehler < 15 FE   : 53.01 %
# Fehler < 20 FE   : 60.13 %
# Fehler = 667 FE : 0.11200 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 37.27
# Fehler < 5 FE   : 0.00 %
# Fehler < 10 FE   : 0.00 %
# Fehler < 15 FE   : 14.23 %
# Fehler < 20 FE   : 27.22 %
# Fehler = 667 FE : 0.20443 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.28
# Fehler < 5 FE   : 60.85 %
# Fehler < 10 FE   : 99.89 %
# Fehler < 15 FE   : 100.00 %
# Fehler < 20 FE   : 100.00 %
# Fehler = 667 FE : 0.00000 %

# %% [markdown]
# # Random Forest Paper

# %%
rf = estimators.MLStatisticalEstimator("RF_hr10")

rf.print_model_test_report("rf-statistical")
# Out:
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.66      0.44      0.53    144049
#     informative       0.49      0.70      0.58    109654
#
#        accuracy                           0.55    253703
#       macro avg       0.58      0.57      0.55    253703
#    weighted avg       0.59      0.55      0.55    253703
#
# MAE auf als informativ klassifizierten Segmenten: 20.14
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 971.59
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 62.02 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 FE gesamt           : 32.61 %
# Fehler < 5 FE klassifiziert    : 24.34 %
# Fehler < 10 FE gesamt          : 43.21 %
# Fehler < 10 FE klassifiziert   : 30.35 %
# Fehler < 15 FE gesamt          : 51.64 %
# Fehler < 15 FE klassifiziert   : 34.66 %
# Fehler < 20 FE gesamt          : 59.38 %
# Fehler < 20 FE klassifiziert   : 38.52 %
# Fehler = 667 FE gesamt         : 0.09578 %
# Fehler = 667 FE klassifiziert  : 0.00236 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5 FE   : 39.25 %
# Fehler < 10 FE   : 48.94 %
# Fehler < 15 FE   : 55.89 %
# Fehler < 20 FE   : 62.11 %
# Fehler = 667 FE : 0.00381 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 36.62
# Fehler < 5 FE   : 0.00 %
# Fehler < 10 FE   : 0.00 %
# Fehler < 15 FE   : 13.60 %
# Fehler < 20 FE   : 25.78 %
# Fehler = 667 FE : 0.00747 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.07
# Fehler < 5 FE   : 64.24 %
# Fehler < 10 FE   : 99.92 %
# Fehler < 15 FE   : 100.00 %
# Fehler < 20 FE   : 100.00 %
# Fehler = 667 FE : 0.00000 %

# %% [markdown]
# # Decision Tree Paper

# %%
dt = estimators.MLStatisticalEstimator("DT_hr10")

dt.print_model_test_report()
# Out:
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.69      0.36      0.48    144049
#     informative       0.49      0.79      0.60    109654
#
#        accuracy                           0.55    253703
#       macro avg       0.59      0.58      0.54    253703
#    weighted avg       0.60      0.55      0.53    253703
#
# MAE auf als informativ klassifizierten Segmenten: 19.47
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 904.82
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 70.39 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 FE gesamt           : 32.61 %
# Fehler < 5 FE klassifiziert    : 26.81 %
# Fehler < 10 FE gesamt          : 43.21 %
# Fehler < 10 FE klassifiziert   : 34.17 %
# Fehler < 15 FE gesamt          : 51.64 %
# Fehler < 15 FE klassifiziert   : 39.56 %
# Fehler < 20 FE gesamt          : 59.38 %
# Fehler < 20 FE klassifiziert   : 44.43 %
# Fehler = 667 FE gesamt         : 0.09578 %
# Fehler = 667 FE klassifiziert  : 0.00355 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5 FE   : 38.08 %
# Fehler < 10 FE   : 48.55 %
# Fehler < 15 FE   : 56.20 %
# Fehler < 20 FE   : 63.12 %
# Fehler = 667 FE : 0.00504 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 34.95
# Fehler < 5 FE   : 0.00 %
# Fehler < 10 FE   : 0.00 %
# Fehler < 15 FE   : 14.85 %
# Fehler < 20 FE   : 28.31 %
# Fehler = 667 FE : 0.00980 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.08
# Fehler < 5 FE   : 64.15 %
# Fehler < 10 FE   : 99.90 %
# Fehler < 15 FE   : 100.00 %
# Fehler < 20 FE   : 100.00 %
# Fehler = 667 FE : 0.00000 %

# %% [markdown]
# # MLP Paper

# %%
mlp = estimators.MLStatisticalEstimator("MLP_hr10")

mlp.print_model_test_report("mlp-statistical")
# Out:
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomizedSearchCV from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.61      0.63      0.62    144049
#     informative       0.50      0.48      0.49    109654
#
#        accuracy                           0.56    253703
#       macro avg       0.55      0.55      0.55    253703
#    weighted avg       0.56      0.56      0.56    253703
#
# MAE auf als informativ klassifizierten Segmenten: 18.41
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 800.14
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 42.04 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 FE gesamt           : 32.61 %
# Fehler < 5 FE klassifiziert    : 16.07 %
# Fehler < 10 FE gesamt          : 43.21 %
# Fehler < 10 FE klassifiziert   : 20.82 %
# Fehler < 15 FE gesamt          : 51.64 %
# Fehler < 15 FE klassifiziert   : 24.34 %
# Fehler < 20 FE gesamt          : 59.38 %
# Fehler < 20 FE klassifiziert   : 27.45 %
# Fehler = 667 FE gesamt         : 0.09578 %
# Fehler = 667 FE klassifiziert  : 0.00000 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5 FE   : 38.22 %
# Fehler < 10 FE   : 49.51 %
# Fehler < 15 FE   : 57.89 %
# Fehler < 20 FE   : 65.29 %
# Fehler = 667 FE : 0.00000 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 33.37
# Fehler < 5 FE   : 0.00 %
# Fehler < 10 FE   : 0.00 %
# Fehler < 15 FE   : 16.59 %
# Fehler < 20 FE   : 31.23 %
# Fehler = 667 FE : 0.00000 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 3.39
# Fehler < 5 FE   : 73.83 %
# Fehler < 10 FE   : 99.96 %
# Fehler < 15 FE   : 100.00 %
# Fehler < 20 FE   : 100.00 %
# Fehler = 667 FE : 0.00000 %

# %% [markdown]
# # SVC Paper

# %%
svc = estimators.MLStatisticalEstimator("SVC_hr10")

svc.print_model_test_report()
# Out:
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Nystroem from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearSVC from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator Pipeline from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/zianor/.virtualenvs/venv/Bachelorarbeit/lib/python3.7/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator RandomizedSearchCV from version 0.23.2 when using version 0.22.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
#  Testset insgesamt
# Fehler < 5 FE   : 32.61 %
# Fehler < 10 FE   : 43.21 %
# Fehler < 15 FE   : 51.64 %
# Fehler < 20 FE   : 59.38 %
# Fehler = 667 FE : 0.09578 %
#                  precision    recall  f1-score   support
#
# non-informative       0.68      0.14      0.23    144049
#     informative       0.45      0.91      0.60    109654
#
#        accuracy                           0.47    253703
#       macro avg       0.56      0.53      0.42    253703
#    weighted avg       0.58      0.47      0.39    253703
#
# MAE auf als informativ klassifizierten Segmenten: 22.06
# MAE auf als informativ annotierten Segmenten:  3.28
# MAE insgesamt:  21.85
# MSE auf als informativ klassifizierten Segmenten: 1496.79
# MSE auf als informativ annotierten Segmenten:  17.83
# MSE insgesamt:  1406.50
#
#
# Coverage klassifiziert      : 88.14 %
# Coverage annotiert          : 43.22 %
#
#  Coverage bestimmter Fehler des genutzten Signals auf Gesamtsignal
# Fehler < 5 FE gesamt           : 32.61 %
# Fehler < 5 FE klassifiziert    : 30.36 %
# Fehler < 10 FE gesamt          : 43.21 %
# Fehler < 10 FE klassifiziert   : 39.39 %
# Fehler < 15 FE gesamt          : 51.64 %
# Fehler < 15 FE klassifiziert   : 46.31 %
# Fehler < 20 FE gesamt          : 59.38 %
# Fehler < 20 FE klassifiziert   : 52.64 %
# Fehler = 667 FE gesamt         : 0.09578 %
# Fehler = 667 FE klassifiziert  : 0.09499 %
#
#  Anteil bestimmter Fehler auf informativem Signal
# Fehler < 5 FE   : 34.45 %
# Fehler < 10 FE   : 44.69 %
# Fehler < 15 FE   : 52.54 %
# Fehler < 20 FE   : 59.72 %
# Fehler = 667 FE : 0.10777 %
#
#  False Positives
# Durchschnittlicher Fehler von False Positives: 37.33
# Fehler < 5 FE   : 0.00 %
# Fehler < 10 FE   : 0.00 %
# Fehler < 15 FE   : 14.17 %
# Fehler < 20 FE   : 27.15 %
# Fehler = 667 FE : 0.19490 %
#
#  False Negatives
# Durchschnittlicher Fehler von False Negatives: 4.43
# Fehler < 5 FE   : 58.70 %
# Fehler < 10 FE   : 99.88 %
# Fehler < 15 FE   : 100.00 %
# Fehler < 20 FE   : 100.00 %
# Fehler = 667 FE : 0.00000 %
